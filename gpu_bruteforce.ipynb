# %% [markdown]
# <a href="https://colab.research.google.com/github/Andre-Dir/Password-Hashing/blob/main/gpu_bruteforce.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from src.cpu.brute_cpu import brute_force_cpu
from src.gpu.brute_gpu import brute_force_gpu

target_hash = "900150983cd24fb0d6963f7d28e17f72"

print("=== CPU ===")
brute_force_cpu(target_hash, 4)

print("\n=== GPU ===")
brute_force_gpu(target_hash, 3)
